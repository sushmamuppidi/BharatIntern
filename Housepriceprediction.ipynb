# %% [markdown]
# importing all the necessary libraries
# As it is of continous data i have used linear regression algorithm for prediction of house price

# %%
import numpy as np
import pandas as pd
import seaborn as sns
#from google.colab import files
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import io

# %% [markdown]
# reading the dataset

# %%
df=pd.read_csv('C:/Users/muppi/Downloads/archive (4)/data.csv')
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %% [markdown]
# finding whether there exists any null values

# %%
print("Total NAN values: ")
print(df.isnull().sum())
print()
print()
print("--------------------info-----------------------")
print()
df.info()
# Out:
# Total NAN values:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64
#
#
# --------------------info-----------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
# ...

# %% [markdown]
# getting the information related to non null count and dtype for each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
#null values
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
# Drop non-numeric columns
numeric_df = df.select_dtypes(include='number')

# Compute correlation matrix
correlation_matrix = numeric_df.corr()

# Print correlation matrix
print(correlation_matrix)
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.200336   0.327110     0.430410  0.050451  0.151461
# bedrooms       0.200336  1.000000   0.545920     0.594884  0.068819  0.177895
# bathrooms      0.327110  0.545920   1.000000     0.761154  0.107837  0.486428
# sqft_living    0.430410  0.594884   0.761154     1.000000  0.210538  0.344850
# sqft_lot       0.050451  0.068819   0.107837     0.210538  1.000000  0.003750
# floors         0.151461  0.177895   0.486428     0.344850  0.003750  1.000000
# waterfront     0.135648 -0.003483   0.076232     0.117616  0.017241  0.022024
# view           0.228504  0.111028   0.211960     0.311009  0.073907  0.031211
# condition      0.034915  0.025080  -0.119994    -0.062826  0.000558 -0.275013
# sqft_above     0.367570  0.484705   0.689918     0.876443  0.216455  0.522814
# sqft_basement  0.210427  0.334165   0.298020     0.447206  0.034842 -0.255510
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %% [markdown]
# Assing the columns of x to input labels i.e features and y to output labels i.e target

# %%
x_columns=['bedrooms','floors','waterfront','sqft_basement','yr_renovated']
y_columns=['price']

x = df[x_columns]
y = df[y_columns]

# %%
x = x.to_numpy().reshape(-1, len(x_columns))
y = y.to_numpy().reshape(-1, len(y_columns))

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
print(x_train,x_test,y_train,y_test)
# Out:
# [[3.000e+00 1.000e+00 0.000e+00 0.000e+00 0.000e+00]
#  [4.000e+00 1.000e+00 0.000e+00 1.120e+03 2.007e+03]
#  [4.000e+00 2.000e+00 0.000e+00 0.000e+00 0.000e+00]
#  ...
#  [4.000e+00 2.000e+00 0.000e+00 0.000e+00 0.000e+00]
#  [3.000e+00 3.000e+00 0.000e+00 0.000e+00 0.000e+00]
#  [3.000e+00 1.000e+00 0.000e+00 0.000e+00 1.989e+03]] [[3.000e+00 3.000e+00 0.000e+00 0.000e+00 2.003e+03]
#  [3.000e+00 2.000e+00 0.000e+00 0.000e+00 0.000e+00]
#  [4.000e+00 1.000e+00 0.000e+00 0.000e+00 0.000e+00]
#  ...
#  [2.000e+00 1.000e+00 0.000e+00 0.000e+00 1.998e+03]
#  [3.000e+00 1.000e+00 0.000e+00 2.400e+02 0.000e+00]
#  [3.000e+00 1.000e+00 0.000e+00 5.000e+02 0.000e+00]] [[ 243800.]
#  [ 875000.]
#  [ 736000.]
#  ...
#  [1485000.]
#  [ 472000.]
#  [ 640000.]] [[ 554250.      ]
#  [ 619000.      ]
#  [ 530000.      ]
#  [ 675000.      ]
#  [ 558000.      ]
#  [7062500.      ]
#  [ 415000.      ]
#  [ 310000.      ]
#  [ 915000.      ]
#  [ 446000.      ]
#  [ 256500.      ]
# ...

# %%
x_train.shape
# Out:
# (3680, 5)

# %%
y_train.shape
# Out:
# (3680, 1)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
import sklearn.metrics as sm
print("Mean absolute error =", (sm.mean_absolute_error(y_test, y_pred)))
print("Mean squared error =", (sm.mean_squared_error(y_test, y_pred)))
print("R^2 score =", (sm.r2_score(y_test, y_pred)))
# Out:
# Mean absolute error = 218374.3297497498
# Mean squared error = 137251886715.81474
# R^2 score = 0.27355058873936855
